# %%
using CSV
using DataFrames
using Serialization
using Dates

# %%
using Distributions
using LinearAlgebra: norm
using ProgressMeter
using BlackBoxOptim
# Out:
# ┌ Info: Precompiling BlackBoxOptim [a134a8b2-14d6-55f6-9291-3336d3ab0209]
# └ @ Base loading.jl:1278

# %%
using Gadfly

# %%
ENV["COLUMNS"] = 1000;

# %%
los_dist_default = (
    icu = Weibull(1.58, 13.32),
    acute = Weibull(1.38, 12.88),
    allbeds = Weibull(1.38, 12.88),
);

# %%
rawdata = DataFrame(CSV.File("../data/hhs_data_2021_02_08.csv"))
# Out:
# 892741×9 DataFrame
#     Row │ hospital                           hospital_id  date        admissions_icu  admissions_acute  admissions_allbeds  active_icu  active_acute   active_allbeds
#         │ String                             String       Date        Float64?        Float64?          Float64?            Float64?    Float64?       Float64?
# ────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       1 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-07-31        0.471429          1.1                  1.57143    1.71429         1.42857         3.14286
#       2 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-01        0.446939          1.04286              1.4898     1.59184         1.73469         3.32653
#       3 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-02        0.422449          0.985714             1.40816    1.46939         2.04082         3.5102
#       4 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-03        0.397959          0.928571             1.32653    1.34694         2.34694         3.69388
#       5 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-04        0.373469          0.871429             1.2449     1.22449         2.65306         3.87755
#       6 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-05        0.34898           0.814286             1.16327    1.10204         2.95918         4.06122
#       7 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-06        0.32449           0.757143             1.08163    0.979592        3.26531         4.2449
#       8 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-07  missing           missing              missing          0.857143  missing         missing
#       9 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-08  missing           missing              missing          0.734694  missing         missing
#      10 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-09  missing           missing              missing          0.612245  missing         missing
#      11 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-10  missing           missing              missing          0.489796  missing         missing
#    ⋮    │                 ⋮                       ⋮           ⋮             ⋮                ⋮                  ⋮               ⋮             ⋮              ⋮
#  892732 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-20        1.16939           2.72857              3.89796    8.30612        28.4898         36.7959
#  892733 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-21        1.07755           2.51429              3.59184    7.93878        26.2449         34.1837
#  892734 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-22        0.985714          2.3                  3.28571    7.57143        24.0            31.5714
#  892735 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-23        0.997959          2.32857              3.32653    7.5102         22.9388         30.449
#  892736 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-24        1.0102            2.35714              3.36735    7.44898        21.8776         29.3265
#  892737 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-25        1.02245           2.38571              3.40816    7.38776        20.8163         28.2041
#  892738 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-26        1.03469           2.41429              3.44898    7.32653        19.7551         27.0816
#  892739 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-27        1.04694           2.44286              3.4898     7.26531        18.6939         25.9592
#  892740 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-28        1.05918           2.47143              3.53061    7.20408        17.6327         24.8367
#  892741 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-29        1.07143           2.5                  3.57143    7.14286        16.5714         23.7143
#                                                                                                                                                    892720 rows omitted

# %%
valuecols = [:admissions_icu, :admissions_acute, :admissions_allbeds, :active_icu, :active_acute, :active_allbeds];

# %%
isbad(x) = isnothing(x) || ismissing(x) || isinf(x) || isnan(x);
isnbad(x) = !isbad(x);

# %%
function interpolate_missing(xs::Array{Union{T,Missing},2}) where T <: Real
    output = Array{Float64,2}(undef, size(xs)...)
    for i in 1:size(xs,1)
        output[i,:] = interpolate_missing(xs[i,:])
    end
    return output
end;

function interpolate_missing(xs::Array{Union{T,Missing},1}) where T <: Real
    if all(isbad.(xs))
        return zeros(T, length(xs))
    end
    
    xs = convert.(Union{Float64,Missing}, deepcopy(xs))
    for i in 1:length(xs)
        if isbad(xs[i])
            a = findprev(isnbad, xs, i)
            b = findnext(isnbad, xs, i)
            
            a = isnothing(a) ? b : a
            b = isnothing(b) ? a : b
            
            m = (a==b) ? 0 : ((xs[b]-xs[a]) / (b-a))
            xs[i] = (m * (i-a)) + xs[a]
        end
    end
    return xs
end;

function interpolate_missing(df_::AbstractDataFrame)
    df = DataFrame(deepcopy(df_))
    for col in valuecols
        df[!,col] = interpolate_missing(df[!,col])
    end
    return df
end;

# %%
function compute_active_nosent(_initial::Array{<:Real,1}, _discharged::Array{<:Real,2},
        _admitted::Array{<:Real,2}, los_dist::Distribution; use_rounding=false)
    N, T = size(_admitted)
    _L = 1.0 .- cdf.(los_dist, 0:T)
    _active = [(
        _initial[i]
        - sum(_discharged[i,1:t])
        + sum(_L[t-t₁+1] * _admitted[i,t₁] for t₁ in 1:t)
    ) for i in 1:N, t in 1:T]
    if use_rounding
        _active = round.(Int, _active)
    end
    return _active
end;

function compute_active_nosent(_initial::Real, _discharged::Array{<:Real,1},
        _admitted::Array{<:Real,1}, los_dist::Distribution; use_rounding=false)
    T = length(_admitted)
    _L = 1.0 .- cdf.(los_dist, 0:T)
    _active = [(
        _initial
        - sum(_discharged[1:t])
        + sum(_L[t-t₁+1] * _admitted[t₁] for t₁ in 1:t)
    ) for t in 1:T]
    if use_rounding
        _active = round.(Int, _active)
    end
    return _active
end;

# %%
function estimate_los(data; optim_time=10.0)
    N, T = data.N, data.T

    function unpack_params(_params)
        alpha, theta = _params
        dist = Gamma(alpha, theta)
        return dist
    end

    function _score_func(params)
        los_dist = unpack_params(params)
        _discharged = [data.initial[i] * pdf(los_dist, t) for i in 1:N, t in 1:T]
        _active = compute_active_nosent(data.initial, _discharged, data.admitted, los_dist, use_rounding=false)
        score = norm(_active - data.active, 2)
        return score
    end

    param_bounds = [(0.0,40.0), (0.0,40.0)]

    r = bboptimize(
        _score_func,
        SearchRange = param_bounds,
        Method = :adaptive_de_rand_1_bin_radiuslimited,
        TraceMode = :silent,
        MaxTime = optim_time,
        RandomizeRngSeed = false,
        RngSeed = 0,
    )

    best_params = best_candidate(r)
    los_dist = unpack_params(best_params)

    return los_dist
end;

# %%
function estimate_los_single(data; optim_time=10.0)
    T = data.T

    function unpack_params(_params)
        alpha, theta = _params
        dist = Gamma(alpha, theta)
        return dist
    end

    function _score_func(params)
        los_dist = unpack_params(params)
        _discharged = [data.initial * pdf(los_dist, t) for t in 1:T]
        _active = compute_active_nosent(data.initial, _discharged, data.admitted, los_dist, use_rounding=false)
        score = norm(_active - data.active, 2)
        return score
    end

    param_bounds = [(0.0,40.0), (0.0,40.0)]

    r = bboptimize(
        _score_func,
        SearchRange = param_bounds,
        Method = :adaptive_de_rand_1_bin_radiuslimited,
        TraceMode = :silent,
        MaxTime = optim_time,
        RandomizeRngSeed = false,
        RngSeed = 0,
    )

    best_params = best_candidate(r)
    los_dist = unpack_params(best_params)

    return los_dist
end;

# %%
function estimate_discharged_simple_all(data, los_dist)
    discharged = [data.initial[i] * pdf(los_dist, t) for i in 1:data.N, t in 1:data.T]
    return discharged
end;

# %%
function estimate_discharged_simple(d, los_dist)
    discharged = [d.initial * pdf(los_dist, t) for t in 1:d.T]
    return discharged
end;

# %%
function extract_data(bedtype)
    hospital_ids = sort(unique(rawdata.hospital_id))
    date_range = sort(unique(rawdata.date))
    
    data_dict = Dict((row.hospital_id, row.date) => (
            active = row["active_$(bedtype)"],
            admissions = row["admissions_$(bedtype )"],
        )
        for row in eachrow(rawdata)
    )
    
    admissions = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].admissions : missing for h in hospital_ids, d in date_range]
    active = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].active : missing for h in hospital_ids, d in date_range]
    
    admissions = interpolate_missing(admissions)
    active = interpolate_missing(active)
    
    return (
        N = length(hospital_ids),
        T = length(date_range),
        date_range = date_range,
        start_date = minimum(date_range),
        end_date = maximum(date_range),
        admitted = admissions,
        active = active,
        initial = active[:,1],
    )
end;

# %%
function extract_data_total(bedtype)
    hospital_ids = sort(unique(rawdata.hospital_id))
    date_range = sort(unique(rawdata.date))
    
    data_dict = Dict((row.hospital_id, row.date) => (
            active = row["active_$(bedtype)"],
            admissions = row["admissions_$(bedtype )"],
        )
        for row in eachrow(rawdata)
    )
    
    admissions = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].admissions : missing for h in hospital_ids, d in date_range]
    active = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].active : missing for h in hospital_ids, d in date_range]
    
    admissions = interpolate_missing(admissions)
    active = interpolate_missing(active)
    
    admissions_total = sum(admissions, dims=1)[:]
    active_total = sum(active, dims=1)[:]
    
    return (
        N = 1,
        T = length(date_range),
        date_range = date_range,
        start_date = minimum(date_range),
        end_date = maximum(date_range),
        admitted = admissions_total,
        active = active_total,
        initial = active_total[1],
    )
end;

# %%
function plot_dist(dist; max_value=50, norm_dist=false, distname="", returnplot=false, showplot=true)

    step = 0.1
    xs = 0 : step : max_value
    
    dist_vals = pdf.(dist, xs)
    dist_vals = norm_dist ? (dist_vals / sum(dist_vals)) : dist_vals
        
    plt = plot(
        layer(
            x = xs,
            y = dist_vals,
            ymax = dist_vals,
            ymin = zeros(length(xs)),
            Geom.ribbon,
            Geom.line,
        ),
        Coord.Cartesian(xmin=0, xmax=max_value, ymax=0.12),
        Guide.xticks(ticks=0:10:max_value),
        Guide.yticks(ticks=0:0.03:0.12),
        Guide.xlabel("LOS"), Guide.ylabel("Frequency"),
        Guide.title("LOS Distribution ($(distname))"),
    )
    
    if showplot
        plt |> SVG(16cm, 10cm)
    end
    
    if returnplot
        return plt
    end
    
    return
end;

# %%
bedtypes = [:icu, :acute, :allbeds];

# %%
data_total = Dict()
for bedtype in bedtypes
    data_total[bedtype] = extract_data_total(bedtype)
end

# %%
los_dist_est = Dict()
for bedtype in bedtypes
    d = data_total[bedtype]
    dist = estimate_los_single(d)
    los_dist_est[bedtype] = dist
end

# %%
for bedtype in bedtypes
    dist = los_dist_est[bedtype]
    plot_dist(dist, distname="$(bedtype) - Estimated")
end
# Out:
# SVG(160.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=24655, maxsize=Inf, ptr=24656, mark=-1), nothing, "img-f6e16a63", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.305000000000007mm, 10.611666666666665mm), (155.0mm, 10.611666666666665mm), (155.0mm, 80.715mm), (20.305000000000007mm, 80.715mm)]) => "img-f6e16a63-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-f6e16a63-36", false, 36, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-f6e16a63-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.305000000000007mm, 10.611666666666665mm), (134.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7651402119438387, 0.1236306792395744, 51.530280423887675, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(160.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=24304, maxsize=Inf, ptr=24305, mark=-1), nothing, "img-982388f2", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.305000000000007mm, 10.611666666666665mm), (155.0mm, 10.611666666666665mm), (155.0mm, 80.715mm), (20.305000000000007mm, 80.715mm)]) => "img-982388f2-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-982388f2-36", false, 36, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-982388f2-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.305000000000007mm, 10.611666666666665mm), (134.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7651402119438387, 0.1236306792395744, 51.530280423887675, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(160.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=24300, maxsize=Inf, ptr=24301, mark=-1), nothing, "img-97459331", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.305000000000007mm, 10.611666666666665mm), (155.0mm, 10.611666666666665mm), (155.0mm, 80.715mm), (20.305000000000007mm, 80.715mm)]) => "img-97459331-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-97459331-36", false, 36, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-97459331-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.305000000000007mm, 10.611666666666665mm), (134.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7651402119438387, 0.1236306792395744, 51.530280423887675, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
for bedtype in bedtypes
    dist = los_dist_est[bedtype]
    println(bedtype)
    println("Mean: $(mean(dist))")
    println("Std: $(std(dist))")
    println()
end
# Out:
# icu
# Mean: 4.99935510415341
# Std: 5.571352437028259
#
# acute
# Mean: 7.682499072565562
# Std: 5.336958158309524
#
# allbeds
# Mean: 7.023416447812837
# Std: 4.981966894840841

# %%
for bedtype in bedtypes
    dist_est = los_dist_est[bedtype]
    dist_default = los_dist_default[bedtype]
    p1 = plot_dist(dist_est, distname="$(bedtype) - Estimated", showplot=false, returnplot=true)
    p2 = plot_dist(dist_default, distname="$(bedtype) - Default", showplot=false, returnplot=true)
    hstack(p1, p2) |> SVG(24cm, 10cm)
end
# Out:
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48371, maxsize=Inf, ptr=48372, mark=-1), nothing, "img-d249ee34", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-d249ee34-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (115.0mm, 10.611666666666665mm), (115.0mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-d249ee34-47"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-d249ee34-79", false, 79, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-d249ee34-5\")\n   .init_gadfly();", "fig.select(\"#img-d249ee34-48\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.69500000000001mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.1025966150283917, 0.1236306792395744, 52.20519323005678, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48488, maxsize=Inf, ptr=48489, mark=-1), nothing, "img-885080dd", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-885080dd-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (114.99999999999999mm, 10.611666666666665mm), (114.99999999999999mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-885080dd-47"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-885080dd-79", false, 79, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-885080dd-5\")\n   .init_gadfly();", "fig.select(\"#img-885080dd-48\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.102596615028392, 0.1236306792395744, 52.20519323005678, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48498, maxsize=Inf, ptr=48499, mark=-1), nothing, "img-97cbd039", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-97cbd039-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (115.0mm, 10.611666666666665mm), (115.0mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-97cbd039-47"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-97cbd039-79", false, 79, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-97cbd039-5\")\n   .init_gadfly();", "fig.select(\"#img-97cbd039-48\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.69500000000001mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.1025966150283917, 0.1236306792395744, 52.20519323005678, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
function score_func(d, los_dist)
    _discharged = [d.initial * pdf(los_dist, t) for t in 1:d.T]
    _active = compute_active_nosent(d.initial, _discharged, d.admitted, los_dist, use_rounding=false)
    score = norm(_active - d.active, 2)
    return score
end;

# %%
for bedtype in bedtypes
    d = data_total[bedtype]
    dist_est = los_dist_est[bedtype]
    dist_default = los_dist_default[bedtype]
    println(bedtype)
    println("Estimate score:\t$(score_func(d, dist_est))")
    println("Default score:\t$(score_func(d, dist_default))")
    println()
end
# Out:
# icu
# Estimate score:	10785.726531392756
# Default score:	242255.13880280312
#
# acute
# Estimate score:	46507.82814611031
# Default score:	357302.54882031097
#
# allbeds
# Estimate score:	41372.25322830015
# Default score:	590623.5052080473

# %%
function plot_estimates_total(data, los_dist)
    _discharged = estimate_discharged_simple(data, los_dist)
    active_computed = compute_active_nosent(
        data.initial,
        _discharged,
        data.admitted,
        los_dist,
    )
    
    colors = Scale.default_discrete_colors(3)[[1,3]]
    
    plt_active_computed = plot(
        layer(x=data.date_range, y=data.active, Geom.point, Geom.line, style(default_color=colors[1])),
        layer(x=data.date_range, y=active_computed, Geom.point, Geom.line, style(default_color=colors[2])),
        Guide.xlabel("Date"), Guide.ylabel("Active COVID Patients"), Guide.title("Total Active COVID Patients - Raw vs Computed"),
        Guide.manual_color_key("", ["Data", "Computed"], colors[[1,2]], shape=[Shape.square], size=[1.6mm]),
        Scale.x_continuous(labels=x -> Dates.format(x, dateformat"yy-mm-dd")),
        Scale.y_continuous(format=:plain),
        Coord.cartesian(ymin=0),
    )

    plt_admitted_computed = plot(
        layer(x=data.date_range, y=data.admitted, Geom.point, Geom.line, style(default_color=colors[1])),
        Guide.xlabel("Date"), Guide.ylabel("Admitted Patients"),
        Guide.title("Total Admitted Patients - Estimated"),
        Scale.x_continuous(labels=x -> Dates.format(x, dateformat"yy-mm-dd")),
        Scale.y_continuous(format=:plain),
    )
    
    plt = hstack(plt_active_computed, plt_admitted_computed)
    plt |> SVG(40cm, 10cm)
        
    return
end;

# %%
plot_estimates_total(data_total[:allbeds], los_dist_default[:allbeds])
plot_estimates_total(data_total[:allbeds], los_dist_est[:allbeds])
# Out:
# SVG(400.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=245735, maxsize=Inf, ptr=245736, mark=-1), nothing, "img-b855f1fd", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(222.97833333333335mm, 10.611666666666665mm), (395.0mm, 10.611666666666665mm), (395.0mm, 80.715mm), (222.97833333333335mm, 80.715mm)]) => "img-b855f1fd-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(24.65166666666667mm, 10.611666666666665mm), (177.42mm, 10.611666666666665mm), (177.42mm, 80.715mm), (24.65166666666667mm, 80.715mm)]) => "img-b855f1fd-607"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-b855f1fd-1740", false, 1740, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-b855f1fd-5\")\n   .init_gadfly();", "fig.select(\"#img-b855f1fd-596\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-b855f1fd-608\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((24.65166666666667mm, 10.611666666666665mm), (152.76833333333332mm, 70.10333333333334mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T13:16:40.173"), 194273.5333905079, Millisecond(16147599655), -199978.7910888244, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(400.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=245460, maxsize=Inf, ptr=245461, mark=-1), nothing, "img-ffe110e6", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(222.97833333333335mm, 10.611666666666665mm), (395.0mm, 10.611666666666665mm), (395.0mm, 80.715mm), (222.97833333333335mm, 80.715mm)]) => "img-ffe110e6-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(24.65166666666667mm, 10.611666666666665mm), (177.42mm, 10.611666666666665mm), (177.42mm, 80.715mm), (24.65166666666667mm, 80.715mm)]) => "img-ffe110e6-607"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-ffe110e6-1738", false, 1738, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-ffe110e6-5\")\n   .init_gadfly();", "fig.select(\"#img-ffe110e6-596\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-ffe110e6-608\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((24.65166666666667mm, 10.611666666666665mm), (152.76833333333332mm, 70.10333333333334mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T13:16:40.173"), 124853.70614763637, Millisecond(16147599655), -128520.30218740836, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
los_dist_est
# Out:
# Dict{Any,Any} with 3 entries:
#   :acute   => Gamma{Float64}(α=2.07213, θ=3.70753)
#   :allbeds => Gamma{Float64}(α=1.98745, θ=3.53389)
#   :icu     => Gamma{Float64}(α=0.805205, θ=6.20879)

# %%
serialize("../data/hhs_los_est.jlser", los_dist_est);
