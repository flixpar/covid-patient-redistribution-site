# %%
using CSV
using DataFrames
using Serialization
using Dates

# %%
using Distributions
using LinearAlgebra: norm
using ProgressMeter
using BlackBoxOptim

# %%
using Gadfly

# %%
ENV["COLUMNS"] = 1000;

# %%
los_dist_default = (
    icu = Weibull(1.58, 13.32),
    acute = Weibull(1.38, 12.88),
    allbeds = Weibull(1.38, 12.88),
);

# %%
rawdata = DataFrame(CSV.File("../data/hhs_data_2021_01_17.csv"))
# Out:
# 790493×9 DataFrame
#     Row │ hospital                           hospital_id  date        admissions_icu  admissions_acute  admissions_allbeds  active_icu  active_acute   active_allbeds
#         │ String                             String       Date        Float64?        Float64?          Float64?            Float64?    Float64?       Float64?
# ────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       1 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-07-31        0.471429          1.1                  1.57143    1.71429         1.42857         3.14286
#       2 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-01        0.446939          1.04286              1.4898     1.59184         1.73469         3.32653
#       3 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-02        0.422449          0.985714             1.40816    1.46939         2.04082         3.5102
#       4 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-03        0.397959          0.928571             1.32653    1.34694         2.34694         3.69388
#       5 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-04        0.373469          0.871429             1.2449     1.22449         2.65306         3.87755
#       6 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-05        0.34898           0.814286             1.16327    1.10204         2.95918         4.06122
#       7 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-06        0.32449           0.757143             1.08163    0.979592        3.26531         4.2449
#       8 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-07  missing           missing              missing          0.857143  missing         missing
#       9 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-08  missing           missing              missing          0.734694  missing         missing
#      10 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-09  missing           missing              missing          0.612245  missing         missing
#      11 │ ABBEVILLE AREA MEDICAL CENTER      421301       2020-08-10  missing           missing              missing          0.489796  missing         missing
#    ⋮    │                 ⋮                       ⋮           ⋮             ⋮                ⋮                  ⋮               ⋮             ⋮              ⋮
#  790484 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2020-12-30        1.42041           3.31429              4.73469    9.77551        23.6939         33.4694
#  790485 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2020-12-31        1.48163           3.45714              4.93878    9.95918        24.0612         34.0204
#  790486 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-01        1.54286           3.6                  5.14286   10.1429         24.4286         34.5714
#  790487 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-02        1.54898           3.61429              5.16327   10.3673         26.2041         36.5714
#  790488 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-03        1.5551            3.62857              5.18367   10.5918         27.9796         38.5714
#  790489 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-04        1.56122           3.64286              5.20408   10.8163         29.7551         40.5714
#  790490 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-05        1.56735           3.65714              5.22449   11.0408         31.5306         42.5714
#  790491 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-06        1.57347           3.67143              5.2449    11.2653         33.3061         44.5714
#  790492 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-07        1.57959           3.68571              5.26531   11.4898         35.0816         46.5714
#  790493 │ ZUCKERBERG SAN FRANCISCO GENERAL…  050228       2021-01-08        1.58571           3.7                  5.28571   11.7143         36.8571         48.5714
#                                                                                                                                                    790472 rows omitted

# %%
valuecols = [:admissions_icu, :admissions_acute, :admissions_allbeds, :active_icu, :active_acute, :active_allbeds];

# %%
isbad(x) = isnothing(x) || ismissing(x) || isinf(x) || isnan(x);
isnbad(x) = !isbad(x);

# %%
function interpolate_missing(xs::Array{Union{T,Missing},2}) where T <: Real
    output = Array{Float64,2}(undef, size(xs)...)
    for i in 1:size(xs,1)
        output[i,:] = interpolate_missing(xs[i,:])
    end
    return output
end;

function interpolate_missing(xs::Array{Union{T,Missing},1}) where T <: Real
    if all(isbad.(xs))
        return zeros(T, length(xs))
    end
    
    xs = convert.(Union{Float64,Missing}, deepcopy(xs))
    for i in 1:length(xs)
        if isbad(xs[i])
            a = findprev(isnbad, xs, i)
            b = findnext(isnbad, xs, i)
            
            a = isnothing(a) ? b : a
            b = isnothing(b) ? a : b
            
            m = (a==b) ? 0 : ((xs[b]-xs[a]) / (b-a))
            xs[i] = (m * (i-a)) + xs[a]
        end
    end
    return xs
end;

function interpolate_missing(df_::AbstractDataFrame)
    df = DataFrame(deepcopy(df_))
    for col in valuecols
        df[!,col] = interpolate_missing(df[!,col])
    end
    return df
end;

# %%
function compute_active_nosent(_initial::Array{<:Real,1}, _discharged::Array{<:Real,2},
        _admitted::Array{<:Real,2}, los_dist::Distribution; use_rounding=false)
    N, T = size(_admitted)
    _L = 1.0 .- cdf.(los_dist, 0:T)
    _active = [(
        _initial[i]
        - sum(_discharged[i,1:t])
        + sum(_L[t-t₁+1] * _admitted[i,t₁] for t₁ in 1:t)
    ) for i in 1:N, t in 1:T]
    if use_rounding
        _active = round.(Int, _active)
    end
    return _active
end;

function compute_active_nosent(_initial::Real, _discharged::Array{<:Real,1},
        _admitted::Array{<:Real,1}, los_dist::Distribution; use_rounding=false)
    T = length(_admitted)
    _L = 1.0 .- cdf.(los_dist, 0:T)
    _active = [(
        _initial
        - sum(_discharged[1:t])
        + sum(_L[t-t₁+1] * _admitted[t₁] for t₁ in 1:t)
    ) for t in 1:T]
    if use_rounding
        _active = round.(Int, _active)
    end
    return _active
end;

# %%
function estimate_los(data; optim_time=10.0)
    N, T = data.N, data.T

    function unpack_params(_params)
        alpha, theta = _params
        dist = Gamma(alpha, theta)
        return dist
    end

    function _score_func(params)
        los_dist = unpack_params(params)
        _discharged = [data.initial[i] * pdf(los_dist, t) for i in 1:N, t in 1:T]
        _active = compute_active_nosent(data.initial, _discharged, data.admitted, los_dist, use_rounding=false)
        score = norm(_active - data.active, 2)
        return score
    end

    param_bounds = [(0.0,40.0), (0.0,40.0)]

    r = bboptimize(
        _score_func,
        SearchRange = param_bounds,
        Method = :adaptive_de_rand_1_bin_radiuslimited,
        TraceMode = :silent,
        MaxTime = optim_time,
        RandomizeRngSeed = false,
        RngSeed = 0,
    )

    best_params = best_candidate(r)
    los_dist = unpack_params(best_params)

    return los_dist
end;

# %%
function estimate_los_single(data; optim_time=10.0)
    T = data.T

    function unpack_params(_params)
        alpha, theta = _params
        dist = Gamma(alpha, theta)
        return dist
    end

    function _score_func(params)
        los_dist = unpack_params(params)
        _discharged = [data.initial * pdf(los_dist, t) for t in 1:T]
        _active = compute_active_nosent(data.initial, _discharged, data.admitted, los_dist, use_rounding=false)
        score = norm(_active - data.active, 2)
        return score
    end

    param_bounds = [(0.0,40.0), (0.0,40.0)]

    r = bboptimize(
        _score_func,
        SearchRange = param_bounds,
        Method = :adaptive_de_rand_1_bin_radiuslimited,
        TraceMode = :silent,
        MaxTime = optim_time,
        RandomizeRngSeed = false,
        RngSeed = 0,
    )

    best_params = best_candidate(r)
    los_dist = unpack_params(best_params)

    return los_dist
end;

# %%
function estimate_discharged_simple_all(data, los_dist)
    discharged = [data.initial[i] * pdf(los_dist, t) for i in 1:data.N, t in 1:data.T]
    return discharged
end;

# %%
function estimate_discharged_simple(d, los_dist)
    discharged = [d.initial * pdf(los_dist, t) for t in 1:d.T]
    return discharged
end;

# %%
function extract_data(bedtype)
    hospital_ids = sort(unique(rawdata.hospital_id))
    date_range = sort(unique(rawdata.date))
    
    data_dict = Dict((row.hospital_id, row.date) => (
            active = row["active_$(bedtype)"],
            admissions = row["admissions_$(bedtype )"],
        )
        for row in eachrow(rawdata)
    )
    
    admissions = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].admissions : missing for h in hospital_ids, d in date_range]
    active = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].active : missing for h in hospital_ids, d in date_range]
    
    admissions = interpolate_missing(admissions)
    active = interpolate_missing(active)
    
    return (
        N = length(hospital_ids),
        T = length(date_range),
        date_range = date_range,
        start_date = minimum(date_range),
        end_date = maximum(date_range),
        admitted = admissions,
        active = active,
        initial = active[:,1],
    )
end;

# %%
function extract_data_total(bedtype)
    hospital_ids = sort(unique(rawdata.hospital_id))
    date_range = sort(unique(rawdata.date))
    
    data_dict = Dict((row.hospital_id, row.date) => (
            active = row["active_$(bedtype)"],
            admissions = row["admissions_$(bedtype )"],
        )
        for row in eachrow(rawdata)
    )
    
    admissions = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].admissions : missing for h in hospital_ids, d in date_range]
    active = [haskey(data_dict, (h,d)) ? data_dict[(h,d)].active : missing for h in hospital_ids, d in date_range]
    
    admissions = interpolate_missing(admissions)
    active = interpolate_missing(active)
    
    admissions_total = sum(admissions, dims=1)[:]
    active_total = sum(active, dims=1)[:]
    
    return (
        N = 1,
        T = length(date_range),
        date_range = date_range,
        start_date = minimum(date_range),
        end_date = maximum(date_range),
        admitted = admissions_total,
        active = active_total,
        initial = active_total[1],
    )
end;

# %%
function plot_dist(dist; max_value=50, norm_dist=false, distname="", returnplot=false, showplot=true)

    step = 0.1
    xs = 0 : step : max_value
    
    dist_vals = pdf.(dist, xs)
    dist_vals = norm_dist ? (dist_vals / sum(dist_vals)) : dist_vals
        
    plt = plot(
        layer(
            x = xs,
            y = dist_vals,
            ymax = dist_vals,
            ymin = zeros(length(xs)),
            Geom.ribbon,
            Geom.line,
        ),
        Coord.Cartesian(xmin=0, xmax=max_value, ymax=0.12),
        Guide.xticks(ticks=0:10:max_value),
        Guide.yticks(ticks=0:0.03:0.12),
        Guide.xlabel("LOS"), Guide.ylabel("Frequency"),
        Guide.title("LOS Distribution ($(distname))"),
    )
    
    if showplot
        plt |> SVG(16cm, 10cm)
    end
    
    if returnplot
        return plt
    end
    
    return
end;

# %%
bedtypes = [:icu, :acute, :allbeds];

# %%
data_total = Dict()
for bedtype in bedtypes
    data_total[bedtype] = extract_data_total(bedtype)
end

# %%
los_dist_est = Dict()
for bedtype in bedtypes
    d = data_total[bedtype]
    dist = estimate_los_single(d)
    los_dist_est[bedtype] = dist
end

# %%
for bedtype in bedtypes
    dist = los_dist_est[bedtype]
    plot_dist(dist, distname="$(bedtype) - Estimated")
end
# Out:
# SVG(160.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=24635, maxsize=Inf, ptr=24636, mark=-1), nothing, "img-972d0e63", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.305000000000007mm, 10.611666666666665mm), (155.0mm, 10.611666666666665mm), (155.0mm, 80.715mm), (20.305000000000007mm, 80.715mm)]) => "img-972d0e63-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-972d0e63-36", false, 36, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-972d0e63-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.305000000000007mm, 10.611666666666665mm), (134.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7651402119438387, 0.1236306792395744, 51.530280423887675, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(160.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=24311, maxsize=Inf, ptr=24312, mark=-1), nothing, "img-cb4f5f3a", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.305000000000007mm, 10.611666666666665mm), (155.0mm, 10.611666666666665mm), (155.0mm, 80.715mm), (20.305000000000007mm, 80.715mm)]) => "img-cb4f5f3a-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-cb4f5f3a-36", false, 36, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-cb4f5f3a-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.305000000000007mm, 10.611666666666665mm), (134.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7651402119438387, 0.1236306792395744, 51.530280423887675, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(160.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=24280, maxsize=Inf, ptr=24281, mark=-1), nothing, "img-051941ce", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.305000000000007mm, 10.611666666666665mm), (155.0mm, 10.611666666666665mm), (155.0mm, 80.715mm), (20.305000000000007mm, 80.715mm)]) => "img-051941ce-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-051941ce-36", false, 36, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-051941ce-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.305000000000007mm, 10.611666666666665mm), (134.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7651402119438387, 0.1236306792395744, 51.530280423887675, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
for bedtype in bedtypes
    dist = los_dist_est[bedtype]
    println(bedtype)
    println("Mean: $(mean(dist))")
    println("Std: $(std(dist))")
    println()
end
# Out:
# icu
# Mean: 4.923731389164289
# Std: 5.534852388151247
#
# acute
# Mean: 7.621901136092607
# Std: 5.243845149662054
#
# allbeds
# Mean: 6.965504115642934
# Std: 4.8638799129643955

# %%
for bedtype in bedtypes
    dist_est = los_dist_est[bedtype]
    dist_default = los_dist_default[bedtype]
    p1 = plot_dist(dist_est, distname="$(bedtype) - Estimated", showplot=false, returnplot=true)
    p2 = plot_dist(dist_default, distname="$(bedtype) - Default", showplot=false, returnplot=true)
    hstack(p1, p2) |> SVG(24cm, 10cm)
end
# Out:
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48351, maxsize=Inf, ptr=48352, mark=-1), nothing, "img-6bb4b9fb", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-6bb4b9fb-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (115.0mm, 10.611666666666665mm), (115.0mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-6bb4b9fb-47"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-6bb4b9fb-79", false, 79, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-6bb4b9fb-5\")\n   .init_gadfly();", "fig.select(\"#img-6bb4b9fb-48\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.69500000000001mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.1025966150283917, 0.1236306792395744, 52.20519323005678, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48495, maxsize=Inf, ptr=48496, mark=-1), nothing, "img-715c450c", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-715c450c-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (114.99999999999999mm, 10.611666666666665mm), (114.99999999999999mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-715c450c-47"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-715c450c-79", false, 79, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-715c450c-5\")\n   .init_gadfly();", "fig.select(\"#img-715c450c-48\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.695mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.102596615028392, 0.1236306792395744, 52.20519323005678, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48478, maxsize=Inf, ptr=48479, mark=-1), nothing, "img-c34eae9b", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-c34eae9b-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (115.0mm, 10.611666666666665mm), (115.0mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-c34eae9b-47"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-c34eae9b-79", false, 79, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-c34eae9b-5\")\n   .init_gadfly();", "fig.select(\"#img-c34eae9b-48\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.69500000000001mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.1025966150283917, 0.1236306792395744, 52.20519323005678, -0.1272613584791488, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
function score_func(d, los_dist)
    _discharged = [d.initial * pdf(los_dist, t) for t in 1:d.T]
    _active = compute_active_nosent(d.initial, _discharged, d.admitted, los_dist, use_rounding=false)
    score = norm(_active - d.active, 2)
    return score
end;

# %%
for bedtype in bedtypes
    d = data_total[bedtype]
    dist_est = los_dist_est[bedtype]
    dist_default = los_dist_default[bedtype]
    println(bedtype)
    println("Estimate score:\t$(score_func(d, dist_est))")
    println("Default score:\t$(score_func(d, dist_default))")
    println()
end
# Out:
# icu
# Estimate score:	10492.959488374643
# Default score:	206513.2233869923
#
# acute
# Estimate score:	44578.7876043115
# Default score:	303689.8987022881
#
# allbeds
# Estimate score:	38756.140302863845
# Default score:	501568.54066207516

# %%
function plot_estimates_total(data, los_dist)
    _discharged = estimate_discharged_simple(data, los_dist)
    active_computed = compute_active_nosent(
        data.initial,
        _discharged,
        data.admitted,
        los_dist,
    )
    
    colors = Scale.default_discrete_colors(3)[[1,3]]
    
    plt_active_computed = plot(
        layer(x=data.date_range, y=data.active, Geom.point, Geom.line, style(default_color=colors[1])),
        layer(x=data.date_range, y=active_computed, Geom.point, Geom.line, style(default_color=colors[2])),
        Guide.xlabel("Date"), Guide.ylabel("Active COVID Patients"), Guide.title("Total Active COVID Patients - Raw vs Computed"),
        Guide.manual_color_key("", ["Data", "Computed"], colors[[1,2]], shape=[Shape.square], size=[1.6mm]),
        Scale.x_continuous(labels=x -> Dates.format(x, dateformat"yy-mm-dd")),
        Scale.y_continuous(format=:plain),
        Coord.cartesian(ymin=0),
    )

    plt_admitted_computed = plot(
        layer(x=data.date_range, y=data.admitted, Geom.point, Geom.line, style(default_color=colors[1])),
        Guide.xlabel("Date"), Guide.ylabel("Admitted Patients"),
        Guide.title("Total Admitted Patients - Estimated"),
        Scale.x_continuous(labels=x -> Dates.format(x, dateformat"yy-mm-dd")),
        Scale.y_continuous(format=:plain),
    )
    
    plt = hstack(plt_active_computed, plt_admitted_computed)
    plt |> SVG(40cm, 10cm)
        
    return
end;

# %%
plot_estimates_total(data_total[:allbeds], los_dist_default[:allbeds])
plot_estimates_total(data_total[:allbeds], los_dist_est[:allbeds])
# Out:
# SVG(400.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=219179, maxsize=Inf, ptr=219180, mark=-1), nothing, "img-93d8d4d7", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(222.97833333333335mm, 10.611666666666665mm), (395.0mm, 10.611666666666665mm), (395.0mm, 80.715mm), (222.97833333333335mm, 80.715mm)]) => "img-93d8d4d7-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(24.65166666666667mm, 10.611666666666665mm), (177.42mm, 10.611666666666665mm), (177.42mm, 80.715mm), (24.65166666666667mm, 80.715mm)]) => "img-93d8d4d7-544"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-93d8d4d7-1551", false, 1551, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-93d8d4d7-5\")\n   .init_gadfly();", "fig.select(\"#img-93d8d4d7-533\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-93d8d4d7-545\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((24.65166666666667mm, 10.611666666666665mm), (152.76833333333332mm, 70.10333333333334mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T20:03:12.46"), 194354.3782149743, Millisecond(14284415079), -200062.01009442142, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
# SVG(400.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=218874, maxsize=Inf, ptr=218875, mark=-1), nothing, "img-66d869d0", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(222.97833333333335mm, 10.611666666666665mm), (395.0mm, 10.611666666666665mm), (395.0mm, 80.715mm), (222.97833333333335mm, 80.715mm)]) => "img-66d869d0-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(24.65166666666667mm, 10.611666666666665mm), (177.42mm, 10.611666666666665mm), (177.42mm, 80.715mm), (24.65166666666667mm, 80.715mm)]) => "img-66d869d0-544"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-66d869d0-1549", false, 1549, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-66d869d0-5\")\n   .init_gadfly();", "fig.select(\"#img-66d869d0-533\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-66d869d0-545\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((24.65166666666667mm, 10.611666666666665mm), (152.76833333333332mm, 70.10333333333334mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T20:03:12.46"), 124349.50636624104, Millisecond(14284415079), -128001.29550136632, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
los_dist_est
# Out:
# Dict{Any,Any} with 3 entries:
#   :acute   => Gamma{Float64}(α=2.11265, θ=3.60775)
#   :allbeds => Gamma{Float64}(α=2.05088, θ=3.39636)
#   :icu     => Gamma{Float64}(α=0.791365, θ=6.22182)

# %%
serialize("../data/hhs_los_est.jlser", los_dist_est);
