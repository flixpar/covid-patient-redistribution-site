# %%
using Serialization
using Dates
using Gadfly

# %%
data = deserialize("../data/data_hhs.jlser");

# %%
date_range = collect(data.start_date : Day(1) : data.end_date);

# %%
plot(
    x = date_range,
    y = sum(data.casesdata[(:moderate, :allbeds)].active, dims=1)[:],
    Scale.y_continuous(format=:plain),
    Geom.point, Geom.line,
    Guide.xlabel("Date"), Guide.ylabel("Active"),
) |> SVG(18cm, 10cm)
# Out:
# SVG(180.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=86239, maxsize=Inf, ptr=86240, mark=-1), nothing, "img-972d0e63", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(24.65166666666667mm, 5.0mm), (175.0mm, 5.0mm), (175.0mm, 80.715mm), (24.65166666666667mm, 80.715mm)]) => "img-972d0e63-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-972d0e63-606", false, 606, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-972d0e63-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((24.65166666666667mm, 5.0mm), (150.34833333333333mm, 75.715mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T09:40:58.532"), 154183.22526668062, Millisecond(16864682937), -158366.45053336123, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
plot(
    x = date_range,
    y = sum(data.casesdata[(:moderate, :allbeds)].admitted, dims=1)[:],
    Geom.point, Geom.line,
    Scale.y_continuous(format=:plain),
    Coord.cartesian(ymin=0),
    Guide.xlabel("Date"), Guide.ylabel("Admissions"),
) |> SVG(18cm, 10cm)
# Out:
# SVG(180.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=86249, maxsize=Inf, ptr=86250, mark=-1), nothing, "img-cb4f5f3a", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(22.978333333333353mm, 5.0mm), (175.00000000000003mm, 5.0mm), (175.00000000000003mm, 80.715mm), (22.978333333333353mm, 80.715mm)]) => "img-cb4f5f3a-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-cb4f5f3a-606", false, 606, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-cb4f5f3a-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((22.978333333333353mm, 5.0mm), (152.02166666666668mm, 75.715mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T10:23:14.634"), 16271.445773690903, Millisecond(16859610733), -16712.914830835063, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
