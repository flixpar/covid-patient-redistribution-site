# %%
using Serialization
using Dates
using Gadfly

# %%
data = deserialize("../data/data_hhs.jlser");

# %%
date_range = collect(data.start_date : Day(1) : data.end_date);

# %%
plot(
    x = date_range,
    y = sum(data.casesdata[(:moderate, :allbeds)].active, dims=1)[:],
    Scale.y_continuous(format=:plain),
    Geom.point, Geom.line,
    Guide.xlabel("Date"), Guide.ylabel("Active"),
) |> SVG(18cm, 10cm)
# Out:
# SVG(180.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=74543, maxsize=Inf, ptr=74544, mark=-1), nothing, "img-ec3a305e", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(24.65166666666667mm, 5.0mm), (175.0mm, 5.0mm), (175.0mm, 80.715mm), (24.65166666666667mm, 80.715mm)]) => "img-ec3a305e-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-ec3a305e-523", false, 523, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-ec3a305e-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((24.65166666666667mm, 5.0mm), (150.34833333333333mm, 75.715mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T18:51:59.38"), 205577.6336889075, Millisecond(14379361241), -211155.26737781498, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
plot(
    x = date_range,
    y = sum(data.casesdata[(:moderate, :allbeds)].admitted, dims=1)[:],
    Geom.point, Geom.line,
    Scale.y_continuous(format=:plain),
    Coord.cartesian(ymin=0),
    Guide.xlabel("Date"), Guide.ylabel("Admissions"),
) |> SVG(18cm, 10cm)
# Out:
# SVG(180.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=73940, maxsize=Inf, ptr=73941, mark=-1), nothing, "img-d9fbb8a6", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.FillOpacityPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(22.978333333333353mm, 5.0mm), (175.0mm, 5.0mm), (175.0mm, 80.715mm), (22.978333333333353mm, 80.715mm)]) => "img-d9fbb8a6-4"), Tuple{Compose.FormPrimitive,String}[], Set{AbstractString}(), true, false, nothing, true, "img-d9fbb8a6-519", false, 519, Set(AbstractString["/Users/flixpar/cs/dev/Gadfly.jl/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-d9fbb8a6-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((22.978333333333353mm, 5.0mm), (152.02166666666665mm, 75.715mm)), Compose.UnitBox{DateTime,Float64,Millisecond,Float64}(DateTime("2020-07-28T19:28:01.74"), 14294.625955067866, Millisecond(14375036519), -14682.460885680846, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
